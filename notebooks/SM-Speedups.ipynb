# %% [markdown]
# # Bayesian Outlier Modeling
# ## For N-of-1 Outlier Analysis of TCGA against Normal Sets
#
# Model outliers using a linear combination of approximations. Each background dataset, $X_i$, for each gene $j$, contributes a posterior distribution of expression $y_{i,j}$ to a linear model that learns the vector of $\beta$ weights corresponding to each background comparison distribution to model an $n$-of-1 tumor sample's distribution $z_j$. Samples drawn from the posterior distribution $z_j$ are then compared to the n-of-1 sample.

# %% [markdown]
# # Inputs

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import pymc3 as pm

import rnaseq_lib3 as r
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
df = pd.read_hdf('/mnt/data/Objects/tcga_gtex_tpm_norm_filt.hd5')
df.head(2)
# Out:
#                                                 id     tissue  \
# GTEX-UTHO-1226-SM-3GAEE    GTEX-UTHO-1226-SM-3GAEE      Heart
# GTEX-146FH-1726-SM-5QGQ2  GTEX-146FH-1726-SM-5QGQ2  Esophagus
#
#                                          subtype tumor label  RP11-40C6.2  \
# GTEX-UTHO-1226-SM-3GAEE   Heart_Atrial_Appendage    no  gtex     0.000000
# GTEX-146FH-1726-SM-5QGQ2        Esophagus_Mucosa    no  gtex     2.970847
#
#                               IGHG1       IGKC       KRT5     IGLC2  \
# GTEX-UTHO-1226-SM-3GAEE   10.302941  10.712460   2.750618  7.780669
# GTEX-146FH-1726-SM-5QGQ2   8.778885  10.445933  12.393268  8.440056
#
#                               ...         IGHEP1  RP11-44N21.4  GAPDHP61  \
# GTEX-UTHO-1226-SM-3GAEE       ...       0.000000           0.0       0.0
# GTEX-146FH-1726-SM-5QGQ2      ...       0.176318           0.0       0.0
#
#                           P2RX5-TAX1BP3  RP11-408H20.3  RP13-726E6.2  \
# GTEX-UTHO-1226-SM-3GAEE        0.150556            0.0      0.000000
# GTEX-146FH-1726-SM-5QGQ2       0.411426            0.0      0.176318
#
#                           CTB-43E15.1    ZNF878     OR2H2  RP4-530I15.9
# GTEX-UTHO-1226-SM-3GAEE           0.0  0.070387  0.790754      0.815589
# GTEX-146FH-1726-SM-5QGQ2          0.0  0.622930  0.042644      0.378503
#
# [2 rows x 26549 columns]

# %%
drug_genes = [x.split('\t')[0] for x in open('../data/druggable-genes.tsv', 'r').readlines()]
drug_genes = [x for x in drug_genes if x in df.columns]
len(drug_genes)
# Out:
# 85

# %% [markdown]
# Subset by dataset

# %%
cols = df.columns[:5].tolist()
drug_df = df[cols + drug_genes]

gtex = df[df.label == 'gtex']
normal = df[df.label == 'tcga-normal']
tumor = df[df.label == 'tcga-tumor']

# %%
def plot_gene_dist(n_of_1, gene):
    plt.axvline(n_of_1[gene], label='n-of-1', color='red')
    sns.kdeplot(gtex[gene], label='gtex')
    sns.kdeplot(normal[gene], label='normal')
    sns.kdeplot(tumor[gene], label='tumor')    
    plt.title(gene);

# %% [markdown]
# # Simple Model

# %% [markdown]
# ## Learn Fits
#
# Learn normal expression fits for all gene / dataset combinations.

# %%
genes = list(set(list(np.random.choice(df.columns[5:], 48, replace=False)) + ['ARAF', 'JAK2']))
len(genes)
# Out:
# 50

# %%
fits = {}
for gene in genes:
    for name, dataset in [('gtex', gtex), ('normal', normal)]:
        key = f'{gene}-{name}'
        fits[key] = st.norm.fit(dataset[gene])

# %% [markdown]
# ## Model

# %%
def simple_model(n_of_1, genes, datasets, fits, n_samples=200, tune=1000):
    """
    n_of_1: tumor sample 
    genes: genes to learn
    datasets: datasets to include
    fits = fits[gene-dataset] contain MAP of expression
    n_samples = Samples to learn
    """
    with pm.Model() as model:
        # Priors for linear model
        alpha = pm.Normal('alpha', 0, 5)
        beta = pm.Normal('beta', 0, 5, shape=len(datasets))
        
        # Convert fits into Normal RVs
        exp_rvs = {key: pm.Normal(key, *fits[key]) for key in fits}
        
        # Define linear model for each gene
        mu = {}
        for i, gene in enumerate(genes):
            mu[gene] = alpha
            for j, ds in enumerate(datasets):
                mu[gene] += exp_rvs[f'{gene}-{ds}'] * beta[j]
        
        # Single sigma across all genes
        sigma = pm.InverseGamma('sigma', 1)
        
        # Define z distributions for each mu
        z = {}
        for i, gene in enumerate(genes):
            obs = n_of_1[gene]
            z[gene] = pm.Laplace(gene, mu=mu[gene], b=sigma, observed=obs)
            
        return model

# %% [markdown]
# ## Sampling Methods
#
# Select an n_of_1 sample and train

# %%
tumor_id = 'TCGA-KK-A7B2-01'
n_of_1 = tumor.loc[tumor_id]

# %%
datasets = ['gtex', 'normal']

# %% [markdown]
# ### Default/Auto

# %%
with pm.Model() as model:
    # Priors for linear model
    alpha = pm.Normal('alpha', 0, 5)
    beta = pm.Normal('beta', 0, 5, shape=len(datasets))

    # Convert fits into Normal RVs
    exp_rvs = {key: pm.Normal(key, *fits[key]) for key in fits}

    # Define linear model for each gene
    mu = {}
    for i, gene in enumerate(genes):
        mu[gene] = alpha
        for j, ds in enumerate(datasets):
            mu[gene] += exp_rvs[f'{gene}-{ds}'] * beta[j]

    # Single sigma across all genes
    sigma = pm.InverseGamma('sigma', 1)

    # Define z distributions for each mu
    z = {}
    for i, gene in enumerate(genes):
        obs = n_of_1[gene]
        z[gene] = pm.Laplace(gene, mu=mu[gene], b=sigma, observed=obs)

# %%
with model:
    trace = pm.sample(200, njobs=12)
# Out:
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [sigma, LINC01123-normal, LINC01123-gtex, GRAMD4P3-normal, GRAMD4P3-gtex, KRTAP16-1-normal, KRTAP16-1-gtex, RP11-120M18.2-normal, RP11-120M18.2-gtex, TXNRD2-normal, TXNRD2-gtex, CROCC-normal, CROCC-gtex, CTU2-normal, CTU2-gtex, RALGAPA2-normal, RALGAPA2-gtex, RP11-102K13.5-normal, RP11-102K13.5-gtex, ARAF-normal, ARAF-gtex, TSPYL6-normal, TSPYL6-gtex, GOLGA2P9-normal, GOLGA2P9-gtex, PCAT7-normal, PCAT7-gtex, RBM6-normal, RBM6-gtex, RP11-469N6.1-normal, RP11-469N6.1-gtex, AC129778.2-normal, AC129778.2-gtex, STAG1-normal, STAG1-gtex, HNRNPKP5-normal, HNRNPKP5-gtex, RP11-206L10.8-normal, RP11-206L10.8-gtex, TMED10-normal, TMED10-gtex, GNL3LP1-normal, GNL3LP1-gtex, USP19-normal, USP19-gtex, ATG3-normal, ATG3-gtex, RP11-324O2.3-normal, RP11-324O2.3-gtex, AC005522.7-normal, AC005522.7-gtex, NOC4L-normal, NOC4L-gtex, SPAG16-normal, SPAG16-gtex, RP11-88E10.5-normal, RP11-88E10.5-gtex, RP4-751H13.7-normal, RP4-751H13.7-gtex, IL6-normal, IL6-gtex, SPHK1-normal, SPHK1-gtex, TBC1D30-normal, TBC1D30-gtex, GCH1-normal, GCH1-gtex, SNORA76C-normal, SNORA76C-gtex, JAK2-normal, JAK2-gtex, CTD-2010I16.1-normal, CTD-2010I16.1-gtex, CTD-2517M22.14-normal, CTD-2517M22.14-gtex, CTC-241N9.1-normal, CTC-241N9.1-gtex, ESRP2-normal, ESRP2-gtex, KIF5B-normal, KIF5B-gtex, SLC39A2-normal, SLC39A2-gtex, VLDLR-AS1-normal, VLDLR-AS1-gtex, RP11-616M22.12-normal, RP11-616M22.12-gtex, SYN2-normal, SYN2-gtex, FAM215B-normal, FAM215B-gtex, WDR17-normal, WDR17-gtex, IGF2BP1-normal, IGF2BP1-gtex, HCG23-normal, HCG23-gtex, TRDC-normal, TRDC-gtex, CTD-2517O10.6-normal, CTD-2517O10.6-gtex, beta, alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [10:28<00:00,  1.01s/draws]
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.traceplot(trace, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ### Default_with_MAP

# %%
with model:
    start = pm.find_MAP()
    trace = pm.sample(200, start=start, njobs=12)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# logp = 35.458, ||grad|| = 472.84: 100%|██████████| 2205/2205 [00:14<00:00, 150.66it/s]
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [sigma, LINC01123-normal, LINC01123-gtex, GRAMD4P3-normal, GRAMD4P3-gtex, KRTAP16-1-normal, KRTAP16-1-gtex, RP11-120M18.2-normal, RP11-120M18.2-gtex, TXNRD2-normal, TXNRD2-gtex, CROCC-normal, CROCC-gtex, CTU2-normal, CTU2-gtex, RALGAPA2-normal, RALGAPA2-gtex, RP11-102K13.5-normal, RP11-102K13.5-gtex, ARAF-normal, ARAF-gtex, TSPYL6-normal, TSPYL6-gtex, GOLGA2P9-normal, GOLGA2P9-gtex, PCAT7-normal, PCAT7-gtex, RBM6-normal, RBM6-gtex, RP11-469N6.1-normal, RP11-469N6.1-gtex, AC129778.2-normal, AC129778.2-gtex, STAG1-normal, STAG1-gtex, HNRNPKP5-normal, HNRNPKP5-gtex, RP11-206L10.8-normal, RP11-206L10.8-gtex, TMED10-normal, TMED10-gtex, GNL3LP1-normal, GNL3LP1-gtex, USP19-normal, USP19-gtex, ATG3-normal, ATG3-gtex, RP11-324O2.3-normal, RP11-324O2.3-gtex, AC005522.7-normal, AC005522.7-gtex, NOC4L-normal, NOC4L-gtex, SPAG16-normal, SPAG16-gtex, RP11-88E10.5-normal, RP11-88E10.5-gtex, RP4-751H13.7-normal, RP4-751H13.7-gtex, IL6-normal, IL6-gtex, SPHK1-normal, SPHK1-gtex, TBC1D30-normal, TBC1D30-gtex, GCH1-normal, GCH1-gtex, SNORA76C-normal, SNORA76C-gtex, JAK2-normal, JAK2-gtex, CTD-2010I16.1-normal, CTD-2010I16.1-gtex, CTD-2517M22.14-normal, CTD-2517M22.14-gtex, CTC-241N9.1-normal, CTC-241N9.1-gtex, ESRP2-normal, ESRP2-gtex, KIF5B-normal, KIF5B-gtex, SLC39A2-normal, SLC39A2-gtex, VLDLR-AS1-normal, VLDLR-AS1-gtex, RP11-616M22.12-normal, RP11-616M22.12-gtex, SYN2-normal, SYN2-gtex, FAM215B-normal, FAM215B-gtex, WDR17-normal, WDR17-gtex, IGF2BP1-normal, IGF2BP1-gtex, HCG23-normal, HCG23-gtex, TRDC-normal, TRDC-gtex, CTD-2517O10.6-normal, CTD-2517O10.6-gtex, beta, alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [11:04<00:00,  1.08s/draws]
# The number of effective samples is smaller than 10% for some parameters.

# %%
pm.traceplot(trace, varnames=['alpha', 'beta', 'sigma'])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f985bc5b908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9854daa390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f984fc423c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f984ea826a0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f984faa7b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f986067bbe0>]],
#       dtype=object)

# %% [markdown]
# ### ADVI

# %%
with model:
    advi = pm.sample(200, init='advi', njobs=12)
# Out:
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi...
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# Average Loss = 67.374:  11%|█         | 21674/200000 [01:16<10:14, 290.37it/s]
# Convergence achieved at 21700
# Interrupted at 21,699 [10%]: Average Loss = 433.39
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [sigma, LINC01123-normal, LINC01123-gtex, GRAMD4P3-normal, GRAMD4P3-gtex, KRTAP16-1-normal, KRTAP16-1-gtex, RP11-120M18.2-normal, RP11-120M18.2-gtex, TXNRD2-normal, TXNRD2-gtex, CROCC-normal, CROCC-gtex, CTU2-normal, CTU2-gtex, RALGAPA2-normal, RALGAPA2-gtex, RP11-102K13.5-normal, RP11-102K13.5-gtex, ARAF-normal, ARAF-gtex, TSPYL6-normal, TSPYL6-gtex, GOLGA2P9-normal, GOLGA2P9-gtex, PCAT7-normal, PCAT7-gtex, RBM6-normal, RBM6-gtex, RP11-469N6.1-normal, RP11-469N6.1-gtex, AC129778.2-normal, AC129778.2-gtex, STAG1-normal, STAG1-gtex, HNRNPKP5-normal, HNRNPKP5-gtex, RP11-206L10.8-normal, RP11-206L10.8-gtex, TMED10-normal, TMED10-gtex, GNL3LP1-normal, GNL3LP1-gtex, USP19-normal, USP19-gtex, ATG3-normal, ATG3-gtex, RP11-324O2.3-normal, RP11-324O2.3-gtex, AC005522.7-normal, AC005522.7-gtex, NOC4L-normal, NOC4L-gtex, SPAG16-normal, SPAG16-gtex, RP11-88E10.5-normal, RP11-88E10.5-gtex, RP4-751H13.7-normal, RP4-751H13.7-gtex, IL6-normal, IL6-gtex, SPHK1-normal, SPHK1-gtex, TBC1D30-normal, TBC1D30-gtex, GCH1-normal, GCH1-gtex, SNORA76C-normal, SNORA76C-gtex, JAK2-normal, JAK2-gtex, CTD-2010I16.1-normal, CTD-2010I16.1-gtex, CTD-2517M22.14-normal, CTD-2517M22.14-gtex, CTC-241N9.1-normal, CTC-241N9.1-gtex, ESRP2-normal, ESRP2-gtex, KIF5B-normal, KIF5B-gtex, SLC39A2-normal, SLC39A2-gtex, VLDLR-AS1-normal, VLDLR-AS1-gtex, RP11-616M22.12-normal, RP11-616M22.12-gtex, SYN2-normal, SYN2-gtex, FAM215B-normal, FAM215B-gtex, WDR17-normal, WDR17-gtex, IGF2BP1-normal, IGF2BP1-gtex, HCG23-normal, HCG23-gtex, TRDC-normal, TRDC-gtex, CTD-2517O10.6-normal, CTD-2517O10.6-gtex, beta, alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [06:30<00:00,  4.86draws/s]
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(advi, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ### ADVI_with_MAP

# %%
with model:
    start = pm.find_MAP()
    advi_w_map = pm.sample(200, start=start, init='advi', njobs=12)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# logp = 35.458, ||grad|| = 472.84: 100%|██████████| 2205/2205 [00:14<00:00, 153.13it/s]
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi...
# Average Loss = 67.735:  10%|█         | 20781/200000 [01:18<11:04, 269.79it/s]
# Convergence achieved at 20800
# Interrupted at 20,799 [10%]: Average Loss = 459.6
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [sigma, LINC01123-normal, LINC01123-gtex, GRAMD4P3-normal, GRAMD4P3-gtex, KRTAP16-1-normal, KRTAP16-1-gtex, RP11-120M18.2-normal, RP11-120M18.2-gtex, TXNRD2-normal, TXNRD2-gtex, CROCC-normal, CROCC-gtex, CTU2-normal, CTU2-gtex, RALGAPA2-normal, RALGAPA2-gtex, RP11-102K13.5-normal, RP11-102K13.5-gtex, ARAF-normal, ARAF-gtex, TSPYL6-normal, TSPYL6-gtex, GOLGA2P9-normal, GOLGA2P9-gtex, PCAT7-normal, PCAT7-gtex, RBM6-normal, RBM6-gtex, RP11-469N6.1-normal, RP11-469N6.1-gtex, AC129778.2-normal, AC129778.2-gtex, STAG1-normal, STAG1-gtex, HNRNPKP5-normal, HNRNPKP5-gtex, RP11-206L10.8-normal, RP11-206L10.8-gtex, TMED10-normal, TMED10-gtex, GNL3LP1-normal, GNL3LP1-gtex, USP19-normal, USP19-gtex, ATG3-normal, ATG3-gtex, RP11-324O2.3-normal, RP11-324O2.3-gtex, AC005522.7-normal, AC005522.7-gtex, NOC4L-normal, NOC4L-gtex, SPAG16-normal, SPAG16-gtex, RP11-88E10.5-normal, RP11-88E10.5-gtex, RP4-751H13.7-normal, RP4-751H13.7-gtex, IL6-normal, IL6-gtex, SPHK1-normal, SPHK1-gtex, TBC1D30-normal, TBC1D30-gtex, GCH1-normal, GCH1-gtex, SNORA76C-normal, SNORA76C-gtex, JAK2-normal, JAK2-gtex, CTD-2010I16.1-normal, CTD-2010I16.1-gtex, CTD-2517M22.14-normal, CTD-2517M22.14-gtex, CTC-241N9.1-normal, CTC-241N9.1-gtex, ESRP2-normal, ESRP2-gtex, KIF5B-normal, KIF5B-gtex, SLC39A2-normal, SLC39A2-gtex, VLDLR-AS1-normal, VLDLR-AS1-gtex, RP11-616M22.12-normal, RP11-616M22.12-gtex, SYN2-normal, SYN2-gtex, FAM215B-normal, FAM215B-gtex, WDR17-normal, WDR17-gtex, IGF2BP1-normal, IGF2BP1-gtex, HCG23-normal, HCG23-gtex, TRDC-normal, TRDC-gtex, CTD-2517O10.6-normal, CTD-2517O10.6-gtex, beta, alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [06:46<00:00,  1.87draws/s]
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(advi_w_map, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ### ADVI+Adapt_diag

# %%
with model:
    advi_adapt = pm.sample(200, init='advi+adapt_diag', njobs=12)
# Out:
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = 67.306:  11%|█         | 22179/200000 [01:23<11:29, 257.74it/s]
# Convergence achieved at 22200
# Interrupted at 22,199 [11%]: Average Loss = 417.25
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [sigma, LINC01123-normal, LINC01123-gtex, GRAMD4P3-normal, GRAMD4P3-gtex, KRTAP16-1-normal, KRTAP16-1-gtex, RP11-120M18.2-normal, RP11-120M18.2-gtex, TXNRD2-normal, TXNRD2-gtex, CROCC-normal, CROCC-gtex, CTU2-normal, CTU2-gtex, RALGAPA2-normal, RALGAPA2-gtex, RP11-102K13.5-normal, RP11-102K13.5-gtex, ARAF-normal, ARAF-gtex, TSPYL6-normal, TSPYL6-gtex, GOLGA2P9-normal, GOLGA2P9-gtex, PCAT7-normal, PCAT7-gtex, RBM6-normal, RBM6-gtex, RP11-469N6.1-normal, RP11-469N6.1-gtex, AC129778.2-normal, AC129778.2-gtex, STAG1-normal, STAG1-gtex, HNRNPKP5-normal, HNRNPKP5-gtex, RP11-206L10.8-normal, RP11-206L10.8-gtex, TMED10-normal, TMED10-gtex, GNL3LP1-normal, GNL3LP1-gtex, USP19-normal, USP19-gtex, ATG3-normal, ATG3-gtex, RP11-324O2.3-normal, RP11-324O2.3-gtex, AC005522.7-normal, AC005522.7-gtex, NOC4L-normal, NOC4L-gtex, SPAG16-normal, SPAG16-gtex, RP11-88E10.5-normal, RP11-88E10.5-gtex, RP4-751H13.7-normal, RP4-751H13.7-gtex, IL6-normal, IL6-gtex, SPHK1-normal, SPHK1-gtex, TBC1D30-normal, TBC1D30-gtex, GCH1-normal, GCH1-gtex, SNORA76C-normal, SNORA76C-gtex, JAK2-normal, JAK2-gtex, CTD-2010I16.1-normal, CTD-2010I16.1-gtex, CTD-2517M22.14-normal, CTD-2517M22.14-gtex, CTC-241N9.1-normal, CTC-241N9.1-gtex, ESRP2-normal, ESRP2-gtex, KIF5B-normal, KIF5B-gtex, SLC39A2-normal, SLC39A2-gtex, VLDLR-AS1-normal, VLDLR-AS1-gtex, RP11-616M22.12-normal, RP11-616M22.12-gtex, SYN2-normal, SYN2-gtex, FAM215B-normal, FAM215B-gtex, WDR17-normal, WDR17-gtex, IGF2BP1-normal, IGF2BP1-gtex, HCG23-normal, HCG23-gtex, TRDC-normal, TRDC-gtex, CTD-2517O10.6-normal, CTD-2517O10.6-gtex, beta, alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [10:33<00:00,  1.44draws/s]
# The number of effective samples is smaller than 10% for some parameters.

# %%
pm.traceplot(advi_adapt, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ### ADVI+Adapt_dig_with_MAP

# %%
with model:
    start = pm.find_MAP()
    advi_adapt_map = pm.sample(200, start=start, init='advi+adapt_diag', njobs=12)
# Out:
# logp = 35.458, ||grad|| = 472.84: 100%|██████████| 2205/2205 [00:14<00:00, 154.11it/s]
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using advi+adapt_diag...
# Average Loss = 67.333:  11%|█         | 21891/200000 [01:17<10:02, 295.81it/s]
# Convergence achieved at 21900
# Interrupted at 21,899 [10%]: Average Loss = 433.24
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [sigma, LINC01123-normal, LINC01123-gtex, GRAMD4P3-normal, GRAMD4P3-gtex, KRTAP16-1-normal, KRTAP16-1-gtex, RP11-120M18.2-normal, RP11-120M18.2-gtex, TXNRD2-normal, TXNRD2-gtex, CROCC-normal, CROCC-gtex, CTU2-normal, CTU2-gtex, RALGAPA2-normal, RALGAPA2-gtex, RP11-102K13.5-normal, RP11-102K13.5-gtex, ARAF-normal, ARAF-gtex, TSPYL6-normal, TSPYL6-gtex, GOLGA2P9-normal, GOLGA2P9-gtex, PCAT7-normal, PCAT7-gtex, RBM6-normal, RBM6-gtex, RP11-469N6.1-normal, RP11-469N6.1-gtex, AC129778.2-normal, AC129778.2-gtex, STAG1-normal, STAG1-gtex, HNRNPKP5-normal, HNRNPKP5-gtex, RP11-206L10.8-normal, RP11-206L10.8-gtex, TMED10-normal, TMED10-gtex, GNL3LP1-normal, GNL3LP1-gtex, USP19-normal, USP19-gtex, ATG3-normal, ATG3-gtex, RP11-324O2.3-normal, RP11-324O2.3-gtex, AC005522.7-normal, AC005522.7-gtex, NOC4L-normal, NOC4L-gtex, SPAG16-normal, SPAG16-gtex, RP11-88E10.5-normal, RP11-88E10.5-gtex, RP4-751H13.7-normal, RP4-751H13.7-gtex, IL6-normal, IL6-gtex, SPHK1-normal, SPHK1-gtex, TBC1D30-normal, TBC1D30-gtex, GCH1-normal, GCH1-gtex, SNORA76C-normal, SNORA76C-gtex, JAK2-normal, JAK2-gtex, CTD-2010I16.1-normal, CTD-2010I16.1-gtex, CTD-2517M22.14-normal, CTD-2517M22.14-gtex, CTC-241N9.1-normal, CTC-241N9.1-gtex, ESRP2-normal, ESRP2-gtex, KIF5B-normal, KIF5B-gtex, SLC39A2-normal, SLC39A2-gtex, VLDLR-AS1-normal, VLDLR-AS1-gtex, RP11-616M22.12-normal, RP11-616M22.12-gtex, SYN2-normal, SYN2-gtex, FAM215B-normal, FAM215B-gtex, WDR17-normal, WDR17-gtex, IGF2BP1-normal, IGF2BP1-gtex, HCG23-normal, HCG23-gtex, TRDC-normal, TRDC-gtex, CTD-2517O10.6-normal, CTD-2517O10.6-gtex, beta, alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [09:11<00:00,  1.50draws/s]
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(advi_adapt_map, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ### Metropolis

# %%
with model:
    step = pm.Metropolis()
    metro = pm.sample(200, step=step, njobs=12)
# Out:
# Only 200 samples in chain.
# Multiprocess sampling (12 chains in 12 jobs)
# CompoundStep
# >Metropolis: [sigma]
# >Metropolis: [SCAMP1-AS1-normal]
# >Metropolis: [SCAMP1-AS1-gtex]
# >Metropolis: [RASGEF1A-normal]
# >Metropolis: [RASGEF1A-gtex]
# >Metropolis: [PPP2R5C-normal]
# >Metropolis: [PPP2R5C-gtex]
# >Metropolis: [MAMDC2-AS1-normal]
# >Metropolis: [MAMDC2-AS1-gtex]
# >Metropolis: [RPLP2-normal]
# >Metropolis: [RPLP2-gtex]
# >Metropolis: [RP11-867G23.4-normal]
# >Metropolis: [RP11-867G23.4-gtex]
# >Metropolis: [ARAF-normal]
# >Metropolis: [ARAF-gtex]
# >Metropolis: [SPIRE2-normal]
# >Metropolis: [SPIRE2-gtex]
# >Metropolis: [ERCC4-normal]
# >Metropolis: [ERCC4-gtex]
# >Metropolis: [XKR8-normal]
# >Metropolis: [XKR8-gtex]
# >Metropolis: [CTC-359D24.3-normal]
# >Metropolis: [CTC-359D24.3-gtex]
# >Metropolis: [OMG-normal]
# >Metropolis: [OMG-gtex]
# >Metropolis: [MARVELD1-normal]
# >Metropolis: [MARVELD1-gtex]
# >Metropolis: [CTD-3116E22.8-normal]
# >Metropolis: [CTD-3116E22.8-gtex]
# >Metropolis: [SDR9C7-normal]
# >Metropolis: [SDR9C7-gtex]
# >Metropolis: [B3GNT2-normal]
# >Metropolis: [B3GNT2-gtex]
# >Metropolis: [MRPS16-normal]
# >Metropolis: [MRPS16-gtex]
# >Metropolis: [TMEM200B-normal]
# >Metropolis: [TMEM200B-gtex]
# >Metropolis: [LCP1-normal]
# >Metropolis: [LCP1-gtex]
# >Metropolis: [KCNH4-normal]
# >Metropolis: [KCNH4-gtex]
# >Metropolis: [RP11-264B17.3-normal]
# >Metropolis: [RP11-264B17.3-gtex]
# >Metropolis: [RP11-505K9.1-normal]
# >Metropolis: [RP11-505K9.1-gtex]
# >Metropolis: [BHLHE40-AS1-normal]
# >Metropolis: [BHLHE40-AS1-gtex]
# >Metropolis: [RN7SL648P-normal]
# >Metropolis: [RN7SL648P-gtex]
# >Metropolis: [SERPINI1-normal]
# >Metropolis: [SERPINI1-gtex]
# >Metropolis: [FTH1P11-normal]
# >Metropolis: [FTH1P11-gtex]
# >Metropolis: [RP11-215A21.2-normal]
# >Metropolis: [RP11-215A21.2-gtex]
# >Metropolis: [WDR83OS-normal]
# >Metropolis: [WDR83OS-gtex]
# >Metropolis: [GTF3C1-normal]
# >Metropolis: [GTF3C1-gtex]
# >Metropolis: [NUB1-normal]
# >Metropolis: [NUB1-gtex]
# >Metropolis: [U91328.19-normal]
# >Metropolis: [U91328.19-gtex]
# >Metropolis: [C15orf57-normal]
# >Metropolis: [C15orf57-gtex]
# >Metropolis: [AC009299.5-normal]
# >Metropolis: [AC009299.5-gtex]
# >Metropolis: [TRBV2-normal]
# >Metropolis: [TRBV2-gtex]
# >Metropolis: [JAK2-normal]
# >Metropolis: [JAK2-gtex]
# >Metropolis: [CTD-2331C18.5-normal]
# >Metropolis: [CTD-2331C18.5-gtex]
# >Metropolis: [SACM1L-normal]
# >Metropolis: [SACM1L-gtex]
# >Metropolis: [TFR2-normal]
# >Metropolis: [TFR2-gtex]
# >Metropolis: [HIST2H3C-normal]
# >Metropolis: [HIST2H3C-gtex]
# >Metropolis: [SLC25A39-normal]
# >Metropolis: [SLC25A39-gtex]
# >Metropolis: [RP3-393E18.2-normal]
# >Metropolis: [RP3-393E18.2-gtex]
# >Metropolis: [RTF1-normal]
# >Metropolis: [RTF1-gtex]
# >Metropolis: [JAZF1-AS1-normal]
# >Metropolis: [JAZF1-AS1-gtex]
# >Metropolis: [RSU1-normal]
# >Metropolis: [RSU1-gtex]
# >Metropolis: [CH507-513H4.3-normal]
# >Metropolis: [CH507-513H4.3-gtex]
# >Metropolis: [NDUFA6-AS1-normal]
# >Metropolis: [NDUFA6-AS1-gtex]
# >Metropolis: [RBM25-normal]
# >Metropolis: [RBM25-gtex]
# >Metropolis: [CARD10-normal]
# >Metropolis: [CARD10-gtex]
# >Metropolis: [AP006621.5-normal]
# >Metropolis: [AP006621.5-gtex]
# >Metropolis: [ZXDB-normal]
# >Metropolis: [ZXDB-gtex]
# >Metropolis: [beta]
# >Metropolis: [alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [03:28<00:00,  8.41draws/s]
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(metro, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ### Metropolis with MAP

# %%
with model:
    start = pm.find_MAP()
    step = pm.Metropolis()
    metro_map = pm.sample(200, step=step, start=start, njobs=12)
# Out:
# logp = 11.881, ||grad|| = 485.73: 100%|██████████| 772/772 [00:05<00:00, 147.75it/s]
# Only 200 samples in chain.
# Multiprocess sampling (12 chains in 12 jobs)
# CompoundStep
# >Metropolis: [sigma]
# >Metropolis: [SCAMP1-AS1-normal]
# >Metropolis: [SCAMP1-AS1-gtex]
# >Metropolis: [RASGEF1A-normal]
# >Metropolis: [RASGEF1A-gtex]
# >Metropolis: [PPP2R5C-normal]
# >Metropolis: [PPP2R5C-gtex]
# >Metropolis: [MAMDC2-AS1-normal]
# >Metropolis: [MAMDC2-AS1-gtex]
# >Metropolis: [RPLP2-normal]
# >Metropolis: [RPLP2-gtex]
# >Metropolis: [RP11-867G23.4-normal]
# >Metropolis: [RP11-867G23.4-gtex]
# >Metropolis: [ARAF-normal]
# >Metropolis: [ARAF-gtex]
# >Metropolis: [SPIRE2-normal]
# >Metropolis: [SPIRE2-gtex]
# >Metropolis: [ERCC4-normal]
# >Metropolis: [ERCC4-gtex]
# >Metropolis: [XKR8-normal]
# >Metropolis: [XKR8-gtex]
# >Metropolis: [CTC-359D24.3-normal]
# >Metropolis: [CTC-359D24.3-gtex]
# >Metropolis: [OMG-normal]
# >Metropolis: [OMG-gtex]
# >Metropolis: [MARVELD1-normal]
# >Metropolis: [MARVELD1-gtex]
# >Metropolis: [CTD-3116E22.8-normal]
# >Metropolis: [CTD-3116E22.8-gtex]
# >Metropolis: [SDR9C7-normal]
# >Metropolis: [SDR9C7-gtex]
# >Metropolis: [B3GNT2-normal]
# >Metropolis: [B3GNT2-gtex]
# >Metropolis: [MRPS16-normal]
# >Metropolis: [MRPS16-gtex]
# >Metropolis: [TMEM200B-normal]
# >Metropolis: [TMEM200B-gtex]
# >Metropolis: [LCP1-normal]
# >Metropolis: [LCP1-gtex]
# >Metropolis: [KCNH4-normal]
# >Metropolis: [KCNH4-gtex]
# >Metropolis: [RP11-264B17.3-normal]
# >Metropolis: [RP11-264B17.3-gtex]
# >Metropolis: [RP11-505K9.1-normal]
# >Metropolis: [RP11-505K9.1-gtex]
# >Metropolis: [BHLHE40-AS1-normal]
# >Metropolis: [BHLHE40-AS1-gtex]
# >Metropolis: [RN7SL648P-normal]
# >Metropolis: [RN7SL648P-gtex]
# >Metropolis: [SERPINI1-normal]
# >Metropolis: [SERPINI1-gtex]
# >Metropolis: [FTH1P11-normal]
# >Metropolis: [FTH1P11-gtex]
# >Metropolis: [RP11-215A21.2-normal]
# >Metropolis: [RP11-215A21.2-gtex]
# >Metropolis: [WDR83OS-normal]
# >Metropolis: [WDR83OS-gtex]
# >Metropolis: [GTF3C1-normal]
# >Metropolis: [GTF3C1-gtex]
# >Metropolis: [NUB1-normal]
# >Metropolis: [NUB1-gtex]
# >Metropolis: [U91328.19-normal]
# >Metropolis: [U91328.19-gtex]
# >Metropolis: [C15orf57-normal]
# >Metropolis: [C15orf57-gtex]
# >Metropolis: [AC009299.5-normal]
# >Metropolis: [AC009299.5-gtex]
# >Metropolis: [TRBV2-normal]
# >Metropolis: [TRBV2-gtex]
# >Metropolis: [JAK2-normal]
# >Metropolis: [JAK2-gtex]
# >Metropolis: [CTD-2331C18.5-normal]
# >Metropolis: [CTD-2331C18.5-gtex]
# >Metropolis: [SACM1L-normal]
# >Metropolis: [SACM1L-gtex]
# >Metropolis: [TFR2-normal]
# >Metropolis: [TFR2-gtex]
# >Metropolis: [HIST2H3C-normal]
# >Metropolis: [HIST2H3C-gtex]
# >Metropolis: [SLC25A39-normal]
# >Metropolis: [SLC25A39-gtex]
# >Metropolis: [RP3-393E18.2-normal]
# >Metropolis: [RP3-393E18.2-gtex]
# >Metropolis: [RTF1-normal]
# >Metropolis: [RTF1-gtex]
# >Metropolis: [JAZF1-AS1-normal]
# >Metropolis: [JAZF1-AS1-gtex]
# >Metropolis: [RSU1-normal]
# >Metropolis: [RSU1-gtex]
# >Metropolis: [CH507-513H4.3-normal]
# >Metropolis: [CH507-513H4.3-gtex]
# >Metropolis: [NDUFA6-AS1-normal]
# >Metropolis: [NDUFA6-AS1-gtex]
# >Metropolis: [RBM25-normal]
# >Metropolis: [RBM25-gtex]
# >Metropolis: [CARD10-normal]
# >Metropolis: [CARD10-gtex]
# >Metropolis: [AP006621.5-normal]
# >Metropolis: [AP006621.5-gtex]
# >Metropolis: [ZXDB-normal]
# >Metropolis: [ZXDB-gtex]
# >Metropolis: [beta]
# >Metropolis: [alpha]
# Sampling 12 chains: 100%|██████████| 8400/8400 [03:56<00:00,  3.74draws/s]
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(metro_map, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# # Center Data

# %%
genes = df.columns[5:]
df_c = df.copy()
df_c[genes] = df_c[genes].apply(lambda x: (x - x.mean()) / x.std())

# %%
gtex_c = df_c[df_c.label == 'gtex']
normal_c = df_c[df_c.label == 'tcga-normal']
tumor_c = df_c[df_c.label == 'tcga-tumor']

# %%
tumor_id = 'TCGA-KK-A7B2-01'
n_of_1 = tumor_c.loc[tumor_id]

# %%
def plot_gene_dist(n_of_1, gene):
    plt.axvline(n_of_1[gene], label='n-of-1', color='red')
    sns.kdeplot(gtex_c[gene], label='gtex')
    sns.kdeplot(normal_c[gene], label='normal')
    sns.kdeplot(tumor_c[gene], label='tumor')    
    plt.title(gene);

# %%
genes = list(set(list(np.random.choice(df.columns[5:], 98, replace=False)) + ['ARAF', 'JAK2']))

fits = {}
for gene in genes:
    for name, dataset in [('gtex', gtex_c), ('normal', normal_c)]:
        key = f'{gene}-{name}'
        fits[key] = st.norm.fit(dataset[gene])
len(fits)
# Out:
# 200

# %%
datasets = ['gtex', 'normal']

# %%
with pm.Model() as model:
    # Priors for linear model
    alpha = pm.Normal('alpha', 0, 5)
    beta = pm.Normal('beta', 0, 5, shape=len(datasets))

    # Convert fits into Normal RVs
    exp_rvs = {key: pm.Normal(key, *fits[key]) for key in fits}

    # Define linear model for each gene
    mu = {}
    for i, gene in enumerate(genes):
        mu[gene] = alpha
        for j, ds in enumerate(datasets):
            mu[gene] += exp_rvs[f'{gene}-{ds}'] * beta[j]

    # Single sigma across all genes
    sigma = pm.InverseGamma('sigma', 1)

    # Define z distributions for each mu
    z = {}
    for i, gene in enumerate(genes):
        obs = n_of_1[gene]
        z[gene] = pm.Laplace(gene, mu=mu[gene], b=sigma, observed=obs)
# Out:
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock

# %%
with model:
    trace = pm.sample(200)
# Out:
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# INFO (theano.gof.compilelock): Refreshing lock /home/ubuntu/.theano/compiledir_Linux-4.15--generic-x86_64-with-debian-buster-sid-x86_64-3.6.6-64/lock_dir/lock
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [sigma, RP11-113K21.6-normal, RP11-113K21.6-gtex, MYH8-normal, MYH8-gtex, ZNF737-normal, ZNF737-gtex, AMHR2-normal, AMHR2-gtex, COLGALT2-normal, COLGALT2-gtex, UNK-normal, UNK-gtex, AF131217.1-normal, AF131217.1-gtex, SDPR-normal, SDPR-gtex, ARG2-normal, ARG2-gtex, PDCD1-normal, PDCD1-gtex, GABRA1-normal, GABRA1-gtex, CKMT2-normal, CKMT2-gtex, TMEM150B-normal, TMEM150B-gtex, FEV-normal, FEV-gtex, RP11-797A18.5-normal, RP11-797A18.5-gtex, SLC27A2-normal, SLC27A2-gtex, RP11-436D23.1-normal, RP11-436D23.1-gtex, SLAIN1-normal, SLAIN1-gtex, RP11-532F6.3-normal, RP11-532F6.3-gtex, TTYH3-normal, TTYH3-gtex, AC108479.2-normal, AC108479.2-gtex, EXOSC5-normal, EXOSC5-gtex, BAALC-normal, BAALC-gtex, ATP6V1E1-normal, ATP6V1E1-gtex, GPR63-normal, GPR63-gtex, LAMTOR5-normal, LAMTOR5-gtex, MRPL35-normal, MRPL35-gtex, APBB2-normal, APBB2-gtex, RGS12-normal, RGS12-gtex, FAM65C-normal, FAM65C-gtex, LEP-normal, LEP-gtex, JAK2-normal, JAK2-gtex, RP11-750H9.5-normal, RP11-750H9.5-gtex, RP11-408A13.3-normal, RP11-408A13.3-gtex, GUCA2A-normal, GUCA2A-gtex, CYP2S1-normal, CYP2S1-gtex, CACNB4-normal, CACNB4-gtex, NOL11-normal, NOL11-gtex, PTPRR-normal, PTPRR-gtex, CTD-2540F13.2-normal, CTD-2540F13.2-gtex, DUS1L-normal, DUS1L-gtex, LHFP-normal, LHFP-gtex, AP1AR-normal, AP1AR-gtex, RP11-849H4.2-normal, RP11-849H4.2-gtex, FZD4-normal, FZD4-gtex, TRAPPC4-normal, TRAPPC4-gtex, ZCRB1-normal, ZCRB1-gtex, SYT3-normal, SYT3-gtex, AC096669.3-normal, AC096669.3-gtex, LAMA1-normal, LAMA1-gtex, AKR7A2-normal, AKR7A2-gtex, ACER1-normal, ACER1-gtex, LL0XNC01-240C2.1-normal, LL0XNC01-240C2.1-gtex, EME1-normal, EME1-gtex, ARAF-normal, ARAF-gtex, CLIP1-normal, CLIP1-gtex, NCSTN-normal, NCSTN-gtex, PIGP-normal, PIGP-gtex, PTBP2-normal, PTBP2-gtex, IMPDH1P10-normal, IMPDH1P10-gtex, RP11-795F19.5-normal, RP11-795F19.5-gtex, MS4A8-normal, MS4A8-gtex, PAFAH1B1-normal, PAFAH1B1-gtex, C17orf67-normal, C17orf67-gtex, C1orf43-normal, C1orf43-gtex, CTD-3141N22.1-normal, CTD-3141N22.1-gtex, AOC1-normal, AOC1-gtex, ETFB-normal, ETFB-gtex, LST1-normal, LST1-gtex, AC010890.1-normal, AC010890.1-gtex, UGP2-normal, UGP2-gtex, RP1-302G2.5-normal, RP1-302G2.5-gtex, SLC14A1-normal, SLC14A1-gtex, STX18-AS1-normal, STX18-AS1-gtex, P3H2-AS1-normal, P3H2-AS1-gtex, YES1-normal, YES1-gtex, CA13-normal, CA13-gtex, GIMAP5-normal, GIMAP5-gtex, COL4A2-normal, COL4A2-gtex, PSPHP1-normal, PSPHP1-gtex, PMS2P10-normal, PMS2P10-gtex, FAM175B-normal, FAM175B-gtex, VWDE-normal, VWDE-gtex, DICER1-AS1-normal, DICER1-AS1-gtex, SBK3-normal, SBK3-gtex, FAM107B-normal, FAM107B-gtex, RP4-539M6.19-normal, RP4-539M6.19-gtex, G3BP2-normal, G3BP2-gtex, RP3-525N10.2-normal, RP3-525N10.2-gtex, CTD-2553L13.9-normal, CTD-2553L13.9-gtex, RN7SL262P-normal, RN7SL262P-gtex, RP11-417N10.4-normal, RP11-417N10.4-gtex, LINC00441-normal, LINC00441-gtex, MSL2-normal, MSL2-gtex, XAGE1B-normal, XAGE1B-gtex, HSPA2-normal, HSPA2-gtex, IGDCC4-normal, IGDCC4-gtex, HIST1H4D-normal, HIST1H4D-gtex, USP16-normal, USP16-gtex, SATB1-AS1-normal, SATB1-AS1-gtex, beta, alpha]
# Sampling 4 chains: 100%|██████████| 2800/2800 [03:52<00:00,  4.85draws/s]
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.traceplot(trace, varnames=['alpha', 'beta', 'sigma']);

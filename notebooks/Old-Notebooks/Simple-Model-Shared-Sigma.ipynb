# %% [markdown]
# # Bayesian Outlier Modeling
# ## For N-of-1 Outlier Analysis of TCGA against Normal Sets
#
# Model outliers using a linear combination of approximations. Each background dataset, $X_i$, for each gene $j$, contributes a posterior distribution of expression $y_{i,j}$ to a linear model that learns the vector of $\beta$ weights corresponding to each background comparison distribution to model an $n$-of-1 tumor sample's distribution $z_j$. Samples drawn from the posterior distribution $z_j$ are then compared to the n-of-1 sample.

# %% [markdown]
# # Inputs

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import pymc3 as pm

import rnaseq_lib3 as r
# Out:
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
df = pd.read_hdf('/mnt/data/Objects/tcga_gtex_tpm_norm_filt.hd5')
df.head(2)
# Out:
#                                                 id     tissue  \
# GTEX-UTHO-1226-SM-3GAEE    GTEX-UTHO-1226-SM-3GAEE      Heart
# GTEX-146FH-1726-SM-5QGQ2  GTEX-146FH-1726-SM-5QGQ2  Esophagus
#
#                                          subtype tumor label  RP11-40C6.2  \
# GTEX-UTHO-1226-SM-3GAEE   Heart_Atrial_Appendage    no  gtex     0.000000
# GTEX-146FH-1726-SM-5QGQ2        Esophagus_Mucosa    no  gtex     2.970847
#
#                               IGHG1       IGKC       KRT5     IGLC2  \
# GTEX-UTHO-1226-SM-3GAEE   10.302941  10.712460   2.750618  7.780669
# GTEX-146FH-1726-SM-5QGQ2   8.778885  10.445933  12.393268  8.440056
#
#                               ...         IGHEP1  RP11-44N21.4  GAPDHP61  \
# GTEX-UTHO-1226-SM-3GAEE       ...       0.000000           0.0       0.0
# GTEX-146FH-1726-SM-5QGQ2      ...       0.176318           0.0       0.0
#
#                           P2RX5-TAX1BP3  RP11-408H20.3  RP13-726E6.2  \
# GTEX-UTHO-1226-SM-3GAEE        0.150556            0.0      0.000000
# GTEX-146FH-1726-SM-5QGQ2       0.411426            0.0      0.176318
#
#                           CTB-43E15.1    ZNF878     OR2H2  RP4-530I15.9
# GTEX-UTHO-1226-SM-3GAEE           0.0  0.070387  0.790754      0.815589
# GTEX-146FH-1726-SM-5QGQ2          0.0  0.622930  0.042644      0.378503
#
# [2 rows x 26549 columns]

# %%
drug_genes = [x.split('\t')[0] for x in open('../data/druggable-genes.tsv', 'r').readlines()]
drug_genes = [x for x in drug_genes if x in df.columns]
len(drug_genes)
# Out:
# 85

# %% [markdown]
# Subset by dataset

# %%
cols = df.columns[:5].tolist()
drug_df = df[cols + drug_genes]

gtex = df[df.label == 'gtex']
normal = df[df.label == 'tcga-normal']
tumor = df[df.label == 'tcga-tumor']

# %%
def plot_gene_dist(n_of_1, gene):
    plt.axvline(n_of_1[gene], label='n-of-1', color='red')
    sns.kdeplot(gtex[gene], label='gtex')
    sns.kdeplot(normal[gene], label='normal')
    sns.kdeplot(tumor[gene], label='tumor')    
    plt.title(gene);

# %% [markdown]
# # Simple Model
#
# PyMC3 doesn't allow `ObservedRVs` to be randomly sampled, so we can't directly learn RVs with observed data, and then randomly sample them as part of our linear model. Since this is a hierarchical model, we want to modify these priors during training anyway, so they can't technically be "observed" as that data is fixed. Which means we have to approximate fits for our gene expression distributions ahead of time, and use those fit parameters as starting parameters for our priors.
#
# **Steps**
# 1. Get normal distribution fits for our gene set
#     1. Using normal just to make things easy for now
# 2. Build Model using two background datasets: GTEx and TCGA-Normal
#     1. We'll later break GTEx and TCGA-Normal up by tissue / disease
# 3. Train
#     1. While my MCMC gently samples
# 4. Use $\alpha$ and $\beta$ parameters learned in the linear model to compute posterior distribution $z_j$ for each gene of interest
# 5. ???
# 6. Profit

# %% [markdown]
# ## Learn Fits
#
# Learn normal expression fits for all gene / dataset combinations.

# %%
genes = list(np.random.choice(df.columns, 98)) + ['ARAF', 'JAK2']

# %%
fits = {}
for gene in genes:
    for name, dataset in [('gtex', gtex), ('normal', normal)]:
        key = f'{gene}-{name}'
        fits[key] = st.norm.fit(dataset[gene])

# %% [markdown]
# ## Build Model

# %%
def train_linear(n_of_1, genes, datasets, fits, n_samples=200, tune=1000):
    """
    n_of_1: tumor sample 
    genes: genes to learn
    datasets: datasets to include
    fits = fits[gene-dataset] contain MAP of expression
    n_samples = Samples to learn
    """
    with pm.Model() as model:
        # Priors for linear model
        alpha = pm.Normal('alpha', 0, 5)
        beta = pm.Normal('beta', 0, 5, shape=len(datasets))
        
        # Single sigma across all genes
        sigma = pm.InverseGamma('sigma', 1)
        
        # Convert fits into Normal RVs
        exp_rvs = {key: pm.Normal(key, *fits[key]) for key in fits}
        
        # Define linear model for each gene
        mu = {}
        for i, gene in enumerate(genes):
            mu[gene] = alpha
            for j, ds in enumerate(datasets):
                mu[gene] += exp_rvs[f'{gene}-{ds}'] * beta[j]
        
        # Define z distributions for each mu
        z = {}
        z_ = {}
        for i, gene in enumerate(genes):
            obs = n_of_1[gene]
            z[gene] = pm.Normal(f'z-{gene}', mu=mu[gene], sd=sigma, observed=obs)
            z_[gene] = pm.Normal(gene, mu=mu[gene], sd=sigma)
        
        # Calculate trace
        trace = pm.sample(n_samples, 
                          tune=tune, 
                          nuts_kwargs={'target_accept': 0.95},
                          njobs=12)
    return model, trace

# %% [markdown]
# ## Train
#
# Select an n_of_1 sample and train

# %%
tumor_id = 'TCGA-KK-A7B2-01'

# %%
n_of_1 = tumor.loc[tumor_id]

# %% [markdown]
# Check that it has an outlier for at least one gene relative to background datasets

# %%
plot_gene_dist(n_of_1, gene='ARAF')

# %% [markdown]
# Find an example gene that is not an outlier

# %%
plot_gene_dist(n_of_1, gene='JAK2')

# %%
datasets = ['gtex', 'normal']
model, trace = train_linear(n_of_1, genes, datasets, fits)
# Out:
# Only 200 samples in chain.
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (12 chains in 12 jobs)
# NUTS: [JAK2, ARAF, TRDN, SLC25A18, MYOCD, GOLGA6A, MAPKAPK2, RP11-742D12.2, RN7SKP163, RBFOX3, TMX1, AC005336.5, FAHD2B, ACAP3, AC104655.2, RP11-304F15.3, CTD-2026D20.3, HIPK3, PDPK1, ISG20, KRT86, DPH2, AL365181.2, TXLNA, G3BP1, GALNT13, CTD-2554C21.2, ERGIC1, RP11-2B6.3, ADK, GS1-24F4.2, CTB-50L17.9, ARFGAP1, RP5-908M14.5, STKLD1, NHLH1, RP11-73M18.7, VASH2, RP11-12A20.7, RP4-568C11.4, ENOX2, NKX2-8, RP11-181C3.1, NEGR1, LPGAT1, GOLGA8A, CAMK2D, ZNF778, AC009238.7, ZSCAN12, GP9, C15orf40, MAMSTR, TAPBPL, PRAP1, RP11-640N20.4, SSR4P1, RP11-643A5.3, CH17-437K3.1, KCNU1, TGFBR3L, ZNF429, RP11-44N21.1, C12orf76, RPL9P29, MRM1, RP11-112L6.3, ZSCAN32, MPG, IGLV10-54, KCNC4, RP11-461A8.5, DXO, SNX30, RP11-680G24.6, PHB2, RGS16, SLC6A7, RP11-76I23.7, HERC2P4, CASC2, CSF3, LYST, DBF4, SMC1A, RP11-259G18.2, OR2W3, STK19B, CACNA1A, RP11-35G9.3, NAPA, KCNAB2, DDX52, U91328.22, KMO, MKRN3, C14orf2, TCF7, ZNF826P, SMDT1, JAK2-normal, JAK2-gtex, ARAF-normal, ARAF-gtex, TRDN-normal, TRDN-gtex, SLC25A18-normal, SLC25A18-gtex, MYOCD-normal, MYOCD-gtex, GOLGA6A-normal, GOLGA6A-gtex, MAPKAPK2-normal, MAPKAPK2-gtex, RP11-742D12.2-normal, RP11-742D12.2-gtex, RN7SKP163-normal, RN7SKP163-gtex, RBFOX3-normal, RBFOX3-gtex, TMX1-normal, TMX1-gtex, AC005336.5-normal, AC005336.5-gtex, FAHD2B-normal, FAHD2B-gtex, ACAP3-normal, ACAP3-gtex, AC104655.2-normal, AC104655.2-gtex, RP11-304F15.3-normal, RP11-304F15.3-gtex, CTD-2026D20.3-normal, CTD-2026D20.3-gtex, HIPK3-normal, HIPK3-gtex, PDPK1-normal, PDPK1-gtex, ISG20-normal, ISG20-gtex, KRT86-normal, KRT86-gtex, DPH2-normal, DPH2-gtex, AL365181.2-normal, AL365181.2-gtex, TXLNA-normal, TXLNA-gtex, G3BP1-normal, G3BP1-gtex, GALNT13-normal, GALNT13-gtex, CTD-2554C21.2-normal, CTD-2554C21.2-gtex, ERGIC1-normal, ERGIC1-gtex, RP11-2B6.3-normal, RP11-2B6.3-gtex, ADK-normal, ADK-gtex, GS1-24F4.2-normal, GS1-24F4.2-gtex, CTB-50L17.9-normal, CTB-50L17.9-gtex, ARFGAP1-normal, ARFGAP1-gtex, RP5-908M14.5-normal, RP5-908M14.5-gtex, STKLD1-normal, STKLD1-gtex, NHLH1-normal, NHLH1-gtex, RP11-73M18.7-normal, RP11-73M18.7-gtex, VASH2-normal, VASH2-gtex, RP11-12A20.7-normal, RP11-12A20.7-gtex, RP4-568C11.4-normal, RP4-568C11.4-gtex, ENOX2-normal, ENOX2-gtex, NKX2-8-normal, NKX2-8-gtex, RP11-181C3.1-normal, RP11-181C3.1-gtex, NEGR1-normal, NEGR1-gtex, LPGAT1-normal, LPGAT1-gtex, GOLGA8A-normal, GOLGA8A-gtex, CAMK2D-normal, CAMK2D-gtex, ZNF778-normal, ZNF778-gtex, AC009238.7-normal, AC009238.7-gtex, ZSCAN12-normal, ZSCAN12-gtex, GP9-normal, GP9-gtex, C15orf40-normal, C15orf40-gtex, MAMSTR-normal, MAMSTR-gtex, TAPBPL-normal, TAPBPL-gtex, PRAP1-normal, PRAP1-gtex, RP11-640N20.4-normal, RP11-640N20.4-gtex, SSR4P1-normal, SSR4P1-gtex, RP11-643A5.3-normal, RP11-643A5.3-gtex, CH17-437K3.1-normal, CH17-437K3.1-gtex, KCNU1-normal, KCNU1-gtex, TGFBR3L-normal, TGFBR3L-gtex, ZNF429-normal, ZNF429-gtex, RP11-44N21.1-normal, RP11-44N21.1-gtex, C12orf76-normal, C12orf76-gtex, RPL9P29-normal, RPL9P29-gtex, MRM1-normal, MRM1-gtex, RP11-112L6.3-normal, RP11-112L6.3-gtex, ZSCAN32-normal, ZSCAN32-gtex, MPG-normal, MPG-gtex, IGLV10-54-normal, IGLV10-54-gtex, KCNC4-normal, KCNC4-gtex, RP11-461A8.5-normal, RP11-461A8.5-gtex, DXO-normal, DXO-gtex, SNX30-normal, SNX30-gtex, RP11-680G24.6-normal, RP11-680G24.6-gtex, PHB2-normal, PHB2-gtex, RGS16-normal, RGS16-gtex, SLC6A7-normal, SLC6A7-gtex, RP11-76I23.7-normal, RP11-76I23.7-gtex, HERC2P4-normal, HERC2P4-gtex, CASC2-normal, CASC2-gtex, CSF3-normal, CSF3-gtex, LYST-normal, LYST-gtex, DBF4-normal, DBF4-gtex, SMC1A-normal, SMC1A-gtex, RP11-259G18.2-normal, RP11-259G18.2-gtex, OR2W3-normal, OR2W3-gtex, STK19B-normal, STK19B-gtex, CACNA1A-normal, CACNA1A-gtex, RP11-35G9.3-normal, RP11-35G9.3-gtex, NAPA-normal, NAPA-gtex, KCNAB2-normal, KCNAB2-gtex, DDX52-normal, DDX52-gtex, U91328.22-normal, U91328.22-gtex, KMO-normal, KMO-gtex, MKRN3-normal, MKRN3-gtex, C14orf2-normal, C14orf2-gtex, TCF7-normal, TCF7-gtex, ZNF826P-normal, ZNF826P-gtex, SMDT1-normal, SMDT1-gtex, sigma, beta, alpha]
# Sampling 12 chains: 100%|██████████| 14400/14400 [41:02<00:00,  1.63s/draws]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.8690407625461005, but should be close to 0.95. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8609317797600702, but should be close to 0.95. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8808539590565349, but should be close to 0.95. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %% [markdown]
# ## TracePlot

# %%
pm.traceplot(trace, varnames=['alpha', 'beta', 'sigma']);

# %% [markdown]
# ## Parameter Estimates

# %%
sns.kdeplot(trace['alpha'], label='alpha')
sns.kdeplot(trace['beta'][:,0], label='beta-gtex')
sns.kdeplot(trace['beta'][:,1], label='beta-normal');
sns.kdeplot(trace['sigma'], label='sigma');

# %% [markdown]
# ## Posterior Sampling

# %%
def posterior_check(trace, gene, n_of_1=n_of_1, gtex=gtex, normal=normal):
    # Get Median of priors
    a = trace['alpha']
    b1 = trace['beta'][:,0]
    b2 = trace['beta'][:,1]
    
    N = len(a)
    
    # 1000 samples from our datasets
    gtex_samples = np.random.choice(gtex[gene], N)
    normal_samples = np.random.choice(normal[gene], N)
    
    # Calculate z based on samples
    z = a + b1 * gtex_samples + b2 * normal_samples
    
    # Calculate PPP
    z_true = n_of_1[gene]
    ppp = sum(z_true < z) / len(z)

    # Plot
    plt.axvline(n_of_1[gene], color='red', label='z-true')
    plt.title(f'{gene} - P: {ppp}')
    sns.kdeplot(z, label='Linear-Equation');

# %%
def posterior_predictive_pval(ppc, gene, n_of_1=n_of_1):
    # Compute PPP
    z = ppc[gene]
    z_true = n_of_1[gene]
    ppp = sum(z_true < z) / len(z)
    
    # Plot
    plt.axvline(n_of_1[gene], color='red', label='z-true')
    plt.title(f'{gene} - P: {ppp}')
    sns.kdeplot(z, label='Posterior');

# %% [markdown]
# Sample from the posterior

# %%
ppc = pm.sample_ppc(trace, model=model)
# Out:
# 100%|██████████| 200/200 [00:40<00:00,  6.28it/s]

# %% [markdown]
# For known non-outlier

# %%
posterior_check(trace, gene='JAK2')

# %%
sns.kdeplot(trace['JAK2'], label='Z-pos')
plt.axvline(n_of_1['JAK2'], label='N-of-1')
sns.kdeplot(ppc['z-JAK2'], label='Z-obs')

# %% [markdown]
# For known outlier

# %%
sns.kdeplot(gtex['ARAF'], c='green', shade=True, alpha=0.25, label='GTEx')
sns.kdeplot(normal['ARAF'], c='blue', shade=True, alpha=0.25, label='Normal')
posterior_check(trace, gene='ARAF')

# %%
sns.kdeplot(gtex['ARAF'], c='green', shade=True, alpha=0.25, label='GTEx')
sns.kdeplot(normal['ARAF'], c='blue', shade=True, alpha=0.25, label='Normal')
posterior_predictive_pval(ppc, 'ARAF')

# %% [markdown]
# # Z* as compared to Z

# %%
sns.kdeplot(gtex['ARAF'], c='green', shade=True, alpha=0.25, label='GTEx')
sns.kdeplot(normal['ARAF'], c='blue', shade=True, alpha=0.25, label='Normal')
posterior_check(trace, 'ARAF')

sns.kdeplot(trace['ARAF'], label='Z*')
sns.kdeplot(ppc['z-ARAF'], label='Z-obs')
